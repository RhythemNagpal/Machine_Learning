# %%
import numpy as np
from numpy import inf

#Defining Distance between the nodes
distance = np.array([[np.inf,10,12,11,14],
                    [10,np.inf,13,15,8],
                    [12,13,np.inf,9,14],
                    [11,15,9,np.inf,16],
                    [14,8,14,16,np.inf]])

num_iterations = 100  # Number of Iterations
num_ants = 6          # Number of ants
num_cities = 5        # Number of Cities

evap_fact = 0.2       # Evaporation Factor
alpha = 1             # Pheromone Factor
beta = 2              # Visibility Factor

# Calculating the visibility of the next city
visibility = 1/distance

#Initializing the pheromone present at paths
pheromone = 0.1*np.ones((num_ants,num_cities))

#Initilizing route of ants which START and END at same city
route = np.ones((num_ants, num_cities+1),int)


#### Optimizing the Tour
for iteration in range(num_iterations):
    print("Iteration : ", iteration+1)
    
    for i in range(num_ants):
        
        #Making the copy of visibility matrix
        temp_visibility = np.copy(visibility)
        
        for j in range(num_cities - 1):
            
            # Gives the current location of the ant
            current_loc = route[i,j] - 1 
            
            # Marking the visited city as Zero
            temp_visibility[:,current_loc] = 0 
            
            # Ant makes decision on what city to go using this decision_feature
            decision_feature = pheromone[current_loc,:] ** alpha * (temp_visibility[current_loc, :] ** beta)
            
            total = np.sum(decision_feature)
            
            # Probabaility of going to next city
            prob = decision_feature / total
            
            # Calculating Cumulative probability
            cum_prob = np.cumsum(prob)
            
            # Generating random number in [0,1)
            r = np.random.random_sample()
            
            # Finding the city having probability higher then random(r)
            city = np.nonzero(cum_prob>r)[0][0]+1 
            route[i,j+1] = city # Adding that city to route
        
        # Adding Untravarsed city to the route
        left_city = list(set([i for i in range(1,num_cities+1)])-set(route[i,:-2]))[0]
        route[i,-2] = left_city
        
        
    # Making the route as optimal route
    optimal_route = np.array(route)
    print("Optiaml Route : ")
    print(optimal_route)
    
    
    #Initializing the cost of the tour for each ant
    dist_cost = np.zeros((num_ants,1),int)
    
    
#### Computation of Total Cost    
    for i in range(num_ants):
        
        sum = 0
        for j in range(num_cities-1):
            
            # Calulating the total distance travelled by each ant
            sum += distance[optimal_route[i,j]-1][optimal_route[i,j+1]-1]
        
        dist_cost[i] = sum
        print("Total Distance Travelled By Ant",i+1," : ",dist_cost[i])
    
    # Finding the index of minimum distance
    dist_min_loc = np.argmin(dist_cost)
    
    # Finding the Minimum Distance
    dist_min_cost = dist_cost[dist_min_loc]
    print("Minimum of Total Distances : ",dist_min_cost)
    
    # Finding the the route which has minimum distance 
    best_route = optimal_route[dist_min_loc,:]
    print()
    print("Best Route after Iteration",iteration + 1, ":", best_route)
    
##### Pheromone Updation   
    for i in range(num_ants):
        for j in range(num_cities-1):
            
            # Updating Pheromone by d which is low when total distance is high
            # and high when total distance is low
            d = 1 / dist_cost[i]
            pheromone[optimal_route[i,j]-1 , optimal_route[i,j+1]-1] += d
    
#### Pheromone Evaporation
    pheromone = (1 - evap_fact) * pheromone
    print("\n")


print("Best Route of all Ants :",best_route)
print()
cost_of_best_path = dist_min_cost + distance[best_route[-2]-1,0]
print("Cost of Best path : ", int(cost_of_best_path))
# Out:
# Iteration :  1
# Optiaml Route :
# [[1 2 4 3 5 1]
#  [1 4 5 2 3 1]
#  [1 2 4 5 3 1]
#  [1 5 2 3 4 1]
#  [1 4 5 2 3 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [48]
# Total Distance Travelled By Ant 2  :  [48]
# Total Distance Travelled By Ant 3  :  [55]
# Total Distance Travelled By Ant 4  :  [44]
# Total Distance Travelled By Ant 5  :  [48]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [43]
#
# Best Route after Iteration 1 : [1 2 5 4 3 1]
#
#
# Iteration :  2
# Optiaml Route :
# [[1 4 3 2 5 1]
#  [1 2 5 4 3 1]
#  [1 4 2 3 5 1]
#  [1 4 3 2 5 1]
#  [1 2 3 4 5 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [53]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [48]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 2 : [1 4 3 2 5 1]
#
#
# Iteration :  3
# Optiaml Route :
# [[1 5 2 4 3 1]
#  [1 3 5 4 2 1]
#  [1 2 4 3 5 1]
#  [1 3 2 5 4 1]
#  [1 5 4 3 2 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [46]
# Total Distance Travelled By Ant 2  :  [57]
# Total Distance Travelled By Ant 3  :  [48]
# Total Distance Travelled By Ant 4  :  [49]
# Total Distance Travelled By Ant 5  :  [52]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [43]
#
# Best Route after Iteration 3 : [1 2 5 4 3 1]
#
#
# Iteration :  4
# Optiaml Route :
# [[1 5 2 3 4 1]
#  [1 4 3 2 5 1]
#  [1 3 5 2 4 1]
#  [1 5 2 3 4 1]
#  [1 5 4 3 2 1]
#  [1 4 5 2 3 1]]
# Total Distance Travelled By Ant 1  :  [44]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [49]
# Total Distance Travelled By Ant 4  :  [44]
# Total Distance Travelled By Ant 5  :  [52]
# Total Distance Travelled By Ant 6  :  [48]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 4 : [1 4 3 2 5 1]
#
#
# Iteration :  5
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 3 5 2 4 1]
#  [1 2 3 4 5 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [49]
# Total Distance Travelled By Ant 4  :  [48]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 5 : [1 2 5 3 4 1]
#
#
# Iteration :  6
# Optiaml Route :
# [[1 2 3 4 5 1]
#  [1 3 5 2 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 4 3 2 5 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [48]
# Total Distance Travelled By Ant 2  :  [49]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 6 : [1 2 5 3 4 1]
#
#
# Iteration :  7
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 3 4 2 5 1]
#  [1 2 3 4 5 1]
#  [1 2 5 4 3 1]
#  [1 5 2 3 4 1]
#  [1 3 2 5 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [44]
# Total Distance Travelled By Ant 3  :  [48]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [44]
# Total Distance Travelled By Ant 6  :  [49]
# Minimum of Total Distances :  [42]
#
# Best Route after Iteration 7 : [1 4 3 5 2 1]
#
#
# Iteration :  8
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 3 4 5 1]
#  [1 2 3 4 5 1]
#  [1 2 3 4 5 1]
#  [1 2 5 4 3 1]
#  [1 5 2 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [48]
# Total Distance Travelled By Ant 3  :  [48]
# Total Distance Travelled By Ant 4  :  [48]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [44]
# Minimum of Total Distances :  [42]
#
# Best Route after Iteration 8 : [1 4 3 5 2 1]
#
#
# Iteration :  9
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 2 3 4 5 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [48]
# Minimum of Total Distances :  [42]
#
# Best Route after Iteration 9 : [1 4 3 5 2 1]
#
#
# Iteration :  10
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 5 4 3 2 1]
#  [1 2 5 4 3 1]
#  [1 4 2 3 5 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [52]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [53]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 10 : [1 2 5 3 4 1]
#
#
# Iteration :  11
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 2 4 3 5 1]
#  [1 2 5 3 4 1]
#  [1 4 3 2 5 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [48]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 11 : [1 2 5 3 4 1]
#
#
# Iteration :  12
# Optiaml Route :
# [[1 3 4 5 2 1]
#  [1 3 4 2 5 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [45]
# Total Distance Travelled By Ant 2  :  [44]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 12 : [1 2 5 3 4 1]
#
#
# Iteration :  13
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 3 4 5 2 1]
#  [1 2 5 4 3 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [45]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 13 : [1 2 5 3 4 1]
#
#
# Iteration :  14
# Optiaml Route :
# [[1 5 2 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 3 4 5 2 1]]
# Total Distance Travelled By Ant 1  :  [44]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [45]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 14 : [1 2 5 3 4 1]
#
#
# Iteration :  15
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 3 4 5 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [48]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 15 : [1 2 5 3 4 1]
#
#
# Iteration :  16
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 3 4 5 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 3 5 2 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [48]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [49]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 16 : [1 2 5 3 4 1]
#
#
# Iteration :  17
# Optiaml Route :
# [[1 4 2 3 5 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [53]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [42]
#
# Best Route after Iteration 17 : [1 4 3 5 2 1]
#
#
# Iteration :  18
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 3 4 2 5 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [44]
# Minimum of Total Distances :  [42]
#
# Best Route after Iteration 18 : [1 4 3 5 2 1]
#
#
# Iteration :  19
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 3 5 2 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [49]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 19 : [1 2 5 3 4 1]
#
#
# Iteration :  20
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 3 4 2 5 1]
#  [1 2 5 4 3 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [44]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [42]
#
# Best Route after Iteration 20 : [1 4 3 5 2 1]
#
#
# Iteration :  21
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 4 3 5 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [48]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 21 : [1 2 5 3 4 1]
#
#
# Iteration :  22
# Optiaml Route :
# [[1 3 4 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 5 2 3 4 1]]
# Total Distance Travelled By Ant 1  :  [45]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [44]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 22 : [1 2 5 3 4 1]
#
#
# Iteration :  23
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 3 4 2 5 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [44]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 23 : [1 2 5 3 4 1]
#
#
# Iteration :  24
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 24 : [1 2 5 3 4 1]
#
#
# Iteration :  25
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 3 5 2 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [49]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 25 : [1 2 5 3 4 1]
#
#
# Iteration :  26
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 3 4 5 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [48]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 26 : [1 2 5 3 4 1]
#
#
# Iteration :  27
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 27 : [1 2 5 3 4 1]
#
#
# Iteration :  28
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 28 : [1 2 5 3 4 1]
#
#
# Iteration :  29
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 29 : [1 2 5 3 4 1]
#
#
# Iteration :  30
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 30 : [1 2 5 3 4 1]
#
#
# Iteration :  31
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 31 : [1 2 5 3 4 1]
#
#
# Iteration :  32
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 32 : [1 2 5 3 4 1]
#
#
# Iteration :  33
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [43]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 33 : [1 2 5 3 4 1]
#
#
# Iteration :  34
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 34 : [1 2 5 3 4 1]
#
#
# Iteration :  35
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 35 : [1 2 5 3 4 1]
#
#
# Iteration :  36
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 36 : [1 2 5 3 4 1]
#
#
# Iteration :  37
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [43]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 37 : [1 2 5 3 4 1]
#
#
# Iteration :  38
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 38 : [1 2 5 3 4 1]
#
#
# Iteration :  39
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 39 : [1 2 5 3 4 1]
#
#
# Iteration :  40
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [43]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 40 : [1 2 5 3 4 1]
#
#
# Iteration :  41
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [43]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 41 : [1 2 5 3 4 1]
#
#
# Iteration :  42
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 42 : [1 2 5 3 4 1]
#
#
# Iteration :  43
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 43 : [1 2 5 3 4 1]
#
#
# Iteration :  44
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 44 : [1 2 5 3 4 1]
#
#
# Iteration :  45
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 45 : [1 2 5 3 4 1]
#
#
# Iteration :  46
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 46 : [1 2 5 3 4 1]
#
#
# Iteration :  47
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 47 : [1 2 5 3 4 1]
#
#
# Iteration :  48
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 48 : [1 2 5 3 4 1]
#
#
# Iteration :  49
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [43]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 49 : [1 2 5 3 4 1]
#
#
# Iteration :  50
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 50 : [1 2 5 3 4 1]
#
#
# Iteration :  51
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 51 : [1 2 5 3 4 1]
#
#
# Iteration :  52
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 52 : [1 2 5 3 4 1]
#
#
# Iteration :  53
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 53 : [1 2 5 3 4 1]
#
#
# Iteration :  54
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 54 : [1 2 5 3 4 1]
#
#
# Iteration :  55
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 55 : [1 2 5 3 4 1]
#
#
# Iteration :  56
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 56 : [1 2 5 3 4 1]
#
#
# Iteration :  57
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 57 : [1 2 5 3 4 1]
#
#
# Iteration :  58
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [42]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 58 : [1 2 5 3 4 1]
#
#
# Iteration :  59
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 59 : [1 2 5 3 4 1]
#
#
# Iteration :  60
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 60 : [1 2 5 3 4 1]
#
#
# Iteration :  61
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 61 : [1 2 5 3 4 1]
#
#
# Iteration :  62
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 4 3 5 2 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [42]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 62 : [1 2 5 3 4 1]
#
#
# Iteration :  63
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 63 : [1 2 5 3 4 1]
#
#
# Iteration :  64
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 64 : [1 2 5 3 4 1]
#
#
# Iteration :  65
# Optiaml Route :
# [[1 2 5 4 3 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [43]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 65 : [1 2 5 3 4 1]
#
#
# Iteration :  66
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 66 : [1 2 5 3 4 1]
#
#
# Iteration :  67
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [42]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 67 : [1 2 5 3 4 1]
#
#
# Iteration :  68
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 68 : [1 2 5 3 4 1]
#
#
# Iteration :  69
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [42]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 69 : [1 2 5 3 4 1]
#
#
# Iteration :  70
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 70 : [1 2 5 3 4 1]
#
#
# Iteration :  71
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 71 : [1 2 5 3 4 1]
#
#
# Iteration :  72
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 72 : [1 2 5 3 4 1]
#
#
# Iteration :  73
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 73 : [1 2 5 3 4 1]
#
#
# Iteration :  74
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 74 : [1 2 5 3 4 1]
#
#
# Iteration :  75
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 75 : [1 2 5 3 4 1]
#
#
# Iteration :  76
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 76 : [1 2 5 3 4 1]
#
#
# Iteration :  77
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 77 : [1 2 5 3 4 1]
#
#
# Iteration :  78
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [42]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 78 : [1 2 5 3 4 1]
#
#
# Iteration :  79
# Optiaml Route :
# [[1 4 3 5 2 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [42]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 79 : [1 2 5 3 4 1]
#
#
# Iteration :  80
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 80 : [1 2 5 3 4 1]
#
#
# Iteration :  81
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 81 : [1 2 5 3 4 1]
#
#
# Iteration :  82
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 82 : [1 2 5 3 4 1]
#
#
# Iteration :  83
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 83 : [1 2 5 3 4 1]
#
#
# Iteration :  84
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 84 : [1 2 5 3 4 1]
#
#
# Iteration :  85
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 85 : [1 2 5 3 4 1]
#
#
# Iteration :  86
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 86 : [1 2 5 3 4 1]
#
#
# Iteration :  87
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 87 : [1 2 5 3 4 1]
#
#
# Iteration :  88
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 88 : [1 2 5 3 4 1]
#
#
# Iteration :  89
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 89 : [1 2 5 3 4 1]
#
#
# Iteration :  90
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 90 : [1 2 5 3 4 1]
#
#
# Iteration :  91
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 91 : [1 2 5 3 4 1]
#
#
# Iteration :  92
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 92 : [1 2 5 3 4 1]
#
#
# Iteration :  93
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 93 : [1 2 5 3 4 1]
#
#
# Iteration :  94
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 94 : [1 2 5 3 4 1]
#
#
# Iteration :  95
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 95 : [1 2 5 3 4 1]
#
#
# Iteration :  96
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 96 : [1 2 5 3 4 1]
#
#
# Iteration :  97
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 97 : [1 2 5 3 4 1]
#
#
# Iteration :  98
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 98 : [1 2 5 3 4 1]
#
#
# Iteration :  99
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 99 : [1 2 5 3 4 1]
#
#
# Iteration :  100
# Optiaml Route :
# [[1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]
#  [1 2 5 3 4 1]]
# Total Distance Travelled By Ant 1  :  [41]
# Total Distance Travelled By Ant 2  :  [41]
# Total Distance Travelled By Ant 3  :  [41]
# Total Distance Travelled By Ant 4  :  [41]
# Total Distance Travelled By Ant 5  :  [41]
# Total Distance Travelled By Ant 6  :  [41]
# Minimum of Total Distances :  [41]
#
# Best Route after Iteration 100 : [1 2 5 3 4 1]
#
#
# Best Route of all Ants : [1 2 5 3 4 1]
#
# Cost of Best path :  52
